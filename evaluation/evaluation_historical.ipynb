# %%
import pandas as pd
from datetime import datetime, timedelta
import json

import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp

from pandas import read_csv
from matplotlib import pyplot
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Amman, Jordan

# %%
def getHistorical(date):
	with open('amman/Amman_Daily_Counts.json') as f:
		data = json.load(f)
		return data[date]

with open('amman/prediction_30_0-2019-prob.json') as f:
	d = json.load(f)
	data = d['payload']
	y_score = []
	y_test = []
	for entry in data:
		predicted = entry['Case_Count']
		actual = getHistorical(entry['Event_Date'])
		if actual>1:
			actual =  2
		y_score.append(predicted)
		y_test.append(actual)

y_score = np.asarray(y_score)
y_test = label_binarize(y_test, classes=[0, 1, 2])

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

n_classes = 3
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

######################################
with open('amman/prediction_30_3-2019-prob.json') as f:
	d = json.load(f)
	data = d['payload']
	y_score1 = []
	y_test1 = []
	for entry in data:
		predicted = entry['Case_Count']
		actual = getHistorical(entry['Event_Date'])
		if actual>1:
			actual = 2
		y_score1.append(predicted)
		y_test1.append(actual)

y_score1 = np.asarray(y_score1)
y_test1 = label_binarize(y_test1, classes=[0, 1, 2])



# Compute ROC curve and ROC area for each class
fpr1 = dict()
tpr1 = dict()
roc_auc1 = dict()
for i in range(3):
    fpr1[i], tpr1[i], _ = roc_curve(y_test1[:, i], y_score1[:, i])
    roc_auc1[i] = auc(fpr1[i], tpr1[i])

# Compute micro-average ROC curve and ROC area
fpr1["micro"], tpr1["micro"], _ = roc_curve(y_test1.ravel(), y_score1.ravel())
roc_auc1["micro"] = auc(fpr1["micro"], tpr1["micro"])

all_fpr1 = np.unique(np.concatenate([fpr1[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr1 = np.zeros_like(all_fpr1)
for i in range(n_classes):
    mean_tpr1 += interp(all_fpr1, fpr1[i], tpr1[i])

# Finally average it and compute AUC
mean_tpr1 /= n_classes

fpr1["macro"] = all_fpr1
tpr1["macro"] = mean_tpr1
roc_auc1["macro"] = auc(fpr1["macro"], tpr1["macro"])

# ###########################
with open('amman/prediction_30_7-2019-prob.json') as f:
	d = json.load(f)
	data = d['payload']
	y_score2 = []
	y_test2 = []
	for entry in data:
		predicted = entry['Case_Count']
		actual = getHistorical(entry['Event_Date'])
		if actual>1:
			actual = 2
		y_score2.append(predicted)
		y_test2.append(actual)

y_score2 = np.asarray(y_score2)
y_test2 = label_binarize(y_test2, classes=[0, 1, 2])

# Compute ROC curve and ROC area for each class
fpr2 = dict()
tpr2 = dict()
roc_auc2 = dict()
for i in range(3):
    fpr2[i], tpr2[i], _ = roc_curve(y_test2[:, i], y_score2[:, i])
    roc_auc2[i] = auc(fpr2[i], tpr2[i])

# Compute micro-average ROC curve and ROC area
fpr2["micro"], tpr2["micro"], _ = roc_curve(y_test2.ravel(), y_score2.ravel())
roc_auc2["micro"] = auc(fpr2["micro"], tpr2["micro"])

all_fpr2 = np.unique(np.concatenate([fpr2[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr2 = np.zeros_like(all_fpr2)
for i in range(n_classes):
    mean_tpr2 += interp(all_fpr2, fpr2[i], tpr2[i])

# Finally average it and compute AUC
mean_tpr2 /= n_classes

fpr2["macro"] = all_fpr2
tpr2["macro"] = mean_tpr2
roc_auc2["macro"] = auc(fpr2["macro"], tpr2["macro"])


################################################################################################
with open('amman/prediction_60_0-2019-prob.json') as f:
	d = json.load(f)
	data = d['payload']
	y_score3 = []
	y_test3 = []
	for entry in data:
		predicted = entry['Case_Count']
		actual = getHistorical(entry['Event_Date'])
		if actual>1:
			actual = 2
		y_score3.append(predicted)
		y_test3.append(actual)

y_score3 = np.asarray(y_score3)
y_test3 = label_binarize(y_test3, classes=[0, 1, 2])



# Compute ROC curve and ROC area for each class
fpr3 = dict()
tpr3 = dict()
roc_auc3 = dict()
for i in range(3):
    fpr3[i], tpr3[i], _ = roc_curve(y_test3[:, i], y_score3[:, i])
    roc_auc3[i] = auc(fpr3[i], tpr3[i])

# Compute micro-average ROC curve and ROC area
fpr3["micro"], tpr3["micro"], _ = roc_curve(y_test3.ravel(), y_score3.ravel())
roc_auc3["micro"] = auc(fpr3["micro"], tpr3["micro"])

all_fpr3 = np.unique(np.concatenate([fpr3[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr3 = np.zeros_like(all_fpr3)
for i in range(n_classes):
    mean_tpr3 += interp(all_fpr3, fpr3[i], tpr3[i])

# Finally average it and compute AUC
mean_tpr3 /= n_classes

fpr3["macro"] = all_fpr3
tpr3["macro"] = mean_tpr3
roc_auc3["macro"] = auc(fpr3["macro"], tpr3["macro"])

######################################
with open('amman/prediction_60_3-2019-prob.json') as f:
	d = json.load(f)
	data = d['payload']
	y_score4 = []
	y_test4 = []
	for entry in data:
		predicted = entry['Case_Count']
		actual = getHistorical(entry['Event_Date'])
		if actual>1:
			actual = 2
		y_score4.append(predicted)
		y_test4.append(actual)

y_score4 = np.asarray(y_score4)
y_test4 = label_binarize(y_test4, classes=[0, 1, 2])

# Compute ROC curve and ROC area for each class
fpr4 = dict()
tpr4 = dict()
roc_auc4 = dict()
for i in range(3):
    fpr4[i], tpr4[i], _ = roc_curve(y_test4[:, i], y_score4[:, i])
    roc_auc4[i] = auc(fpr4[i], tpr4[i])

# Compute micro-average ROC curve and ROC area
fpr4["micro"], tpr4["micro"], _ = roc_curve(y_test4.ravel(), y_score4.ravel())
roc_auc4["micro"] = auc(fpr4["micro"], tpr4["micro"])

all_fpr4 = np.unique(np.concatenate([fpr4[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr4 = np.zeros_like(all_fpr4)
for i in range(n_classes):
    mean_tpr4 += interp(all_fpr4, fpr4[i], tpr4[i])

# Finally average it and compute AUC
mean_tpr4 /= n_classes

fpr4["macro"] = all_fpr4
tpr4["macro"] = mean_tpr4
roc_auc4["macro"] = auc(fpr4["macro"], tpr4["macro"])

# ###########################
with open('amman/prediction_60_7-2019-prob.json') as f:
	d = json.load(f)
	data = d['payload']
	y_score5 = []
	y_test5 = []
	for entry in data:
		predicted = entry['Case_Count']
		actual = getHistorical(entry['Event_Date'])
		if actual>1:
			actual = 2
		y_score5.append(predicted)
		y_test5.append(actual)

y_score5 = np.asarray(y_score5)
y_test5 = label_binarize(y_test5, classes=[0, 1, 2])

# Compute ROC curve and ROC area for each class
fpr5 = dict()
tpr5 = dict()
roc_auc5 = dict()
for i in range(3):
    fpr5[i], tpr5[i], _ = roc_curve(y_test5[:, i], y_score5[:, i])
    roc_auc5[i] = auc(fpr5[i], tpr5[i])

# Compute micro-average ROC curve and ROC area
fpr5["micro"], tpr5["micro"], _ = roc_curve(y_test5.ravel(), y_score5.ravel())
roc_auc5["micro"] = auc(fpr5["micro"], tpr5["micro"])

all_fpr5 = np.unique(np.concatenate([fpr5[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr5 = np.zeros_like(all_fpr5)
for i in range(n_classes):
    mean_tpr5 += interp(all_fpr5, fpr5[i], tpr5[i])

# Finally average it and compute AUC
mean_tpr5 /= n_classes

fpr5["macro"] = all_fpr5
tpr5["macro"] = mean_tpr5
roc_auc5["macro"] = auc(fpr5["macro"], tpr5["macro"])

################################################################################################
def parser(x):
	return datetime.strptime(x, '%Y-%m-%d')
 
series = read_csv('../arima/amman.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
X = series.values.astype('float32')
size = int(len(X) * 0.95)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
	model = ARIMA(history, order=(5,1,0))
	model_fit = model.fit(disp=0)
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)

y_score6 = []
y_test6 = []
for i in range(len(predictions)):
	predicted = np.rint(predictions[i])
	if predicted > 1:
		predicted = 2
	actual = np.rint(test[i])
	if test[i]>1:
		actual = 2
	y_score6.append(predicted)
	y_test6.append(actual)

y_score6 = label_binarize(y_score6, classes=[0, 1, 2])
y_test6 = label_binarize(y_test6, classes=[0, 1, 2])


# Compute ROC curve and ROC area for each class
fpr6 = dict()
tpr6 = dict()
roc_auc6 = dict()
for i in range(3):
    fpr6[i], tpr6[i], _ = roc_curve(y_test6[:, i], y_score6[:, i])
    roc_auc6[i] = auc(fpr6[i], tpr6[i])

# Compute micro-average ROC curve and ROC area
fpr6["micro"], tpr6["micro"], _ = roc_curve(y_test6.ravel(), y_score6.ravel())
roc_auc6["micro"] = auc(fpr6["micro"], tpr6["micro"])


all_fpr6 = np.unique(np.concatenate([fpr6[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr6 = np.zeros_like(all_fpr6)
for i in range(n_classes):
    mean_tpr6 += interp(all_fpr6, fpr6[i], tpr6[i])

# Finally average it and compute AUC
mean_tpr6 /= n_classes

fpr6["macro"] = all_fpr6
tpr6["macro"] = mean_tpr6
roc_auc6["macro"] = auc(fpr6["macro"], tpr6["macro"])
################################################################################################

plt.figure()
lw = 2
plt.plot(fpr['macro'], tpr['macro'], color='blue',
         lw=lw, label='30 days 0 LT (area = %0.2f)' % roc_auc['macro'], linestyle=':')
plt.plot(fpr1['macro'], tpr1['macro'], color='blue',
         lw=lw, label='30 days 3 LT (area = %0.2f)' % roc_auc1['macro'], linestyle='--')
plt.plot(fpr2['macro'], tpr2['macro'], color='blue',
         lw=lw, label='30 days 7 LT (area = %0.2f)' % roc_auc2['macro'], linestyle='-.')
plt.plot(fpr3['macro'], tpr3['macro'], color='red',
         lw=lw, label='60 days 0 LT (area = %0.2f)' % roc_auc3['macro'], linestyle=':')
plt.plot(fpr4['macro'], tpr4['macro'], color='red',
         lw=lw, label='60 days 3 LT (area = %0.2f)' % roc_auc4['macro'], linestyle='--')
plt.plot(fpr5['macro'], tpr5['macro'], color='red',
         lw=lw, label='60 days 7 LT (area = %0.2f)' % roc_auc5['macro'], linestyle='-.')
plt.plot(fpr6['macro'], tpr6['macro'], color='green',
         lw=lw, label='ARIMA (area = %0.2f)' % roc_auc6['macro'])
# plt.plot([0, 1], [0, 1], color='green', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('macro-average AUC-ROC curve for Amman, Jordan')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Cairo, Egypt

# %%
def getHistorical(date):
	with open('cairo/Cairo_Daily_Counts.json') as f:
		data = json.load(f)
		return data[date]


with open('cairo/prediction_30_0-2019-prob.json') as f:
	d = json.load(f)
	data = d['payload']
	y_score = []
	y_test = []
	for entry in data:
		predicted = entry['Case_Count']
		actual = getHistorical(entry['Event_Date'])
		if actual>1:
			actual =  2
		y_score.append(predicted)
		y_test.append(actual)

y_score = np.asarray(y_score)
y_test = label_binarize(y_test, classes=[0, 1, 2])

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(2):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

n_classes = 2
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

######################################
with open('cairo/prediction_30_3-2019-prob.json') as f:
	d = json.load(f)
	data = d['payload']
	y_score1 = []
	y_test1 = []
	for entry in data:
		# if entry['Case_Count']!=2:
		predicted = entry['Case_Count']
		# if predicted>1:
		# 	predicted = 2
		actual = getHistorical(entry['Event_Date'])
		if actual>1:
			actual = 2
		y_score1.append(predicted)
		y_test1.append(actual)

y_score1 = np.asarray(y_score1)
y_test1 = label_binarize(y_test1, classes=[0, 1, 2])



# Compute ROC curve and ROC area for each class
fpr1 = dict()
tpr1 = dict()
roc_auc1 = dict()
for i in range(2):
    fpr1[i], tpr1[i], _ = roc_curve(y_test1[:, i], y_score1[:, i])
    roc_auc1[i] = auc(fpr1[i], tpr1[i])

# Compute micro-average ROC curve and ROC area
fpr1["micro"], tpr1["micro"], _ = roc_curve(y_test1.ravel(), y_score1.ravel())
roc_auc1["micro"] = auc(fpr1["micro"], tpr1["micro"])

all_fpr1 = np.unique(np.concatenate([fpr1[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr1 = np.zeros_like(all_fpr1)
for i in range(n_classes):
    mean_tpr1 += interp(all_fpr1, fpr1[i], tpr1[i])

# Finally average it and compute AUC
mean_tpr1 /= n_classes

fpr1["macro"] = all_fpr1
tpr1["macro"] = mean_tpr1
roc_auc1["macro"] = auc(fpr1["macro"], tpr1["macro"])

# ###########################
with open('cairo/prediction_30_7-2019-prob.json') as f:
	d = json.load(f)
	data = d['payload']
	y_score2 = []
	y_test2 = []
	for entry in data:
		predicted = entry['Case_Count']
		actual = getHistorical(entry['Event_Date'])
		if actual>1:
			actual = 2
		y_score2.append(predicted)
		y_test2.append(actual)

y_score2 = np.asarray(y_score2)
y_test2 = label_binarize(y_test2, classes=[0, 1, 2])

# Compute ROC curve and ROC area for each class
fpr2 = dict()
tpr2 = dict()
roc_auc2 = dict()
for i in range(2):
    fpr2[i], tpr2[i], _ = roc_curve(y_test2[:, i], y_score2[:, i])
    roc_auc2[i] = auc(fpr2[i], tpr2[i])

# Compute micro-average ROC curve and ROC area
fpr2["micro"], tpr2["micro"], _ = roc_curve(y_test2.ravel(), y_score2.ravel())
roc_auc2["micro"] = auc(fpr2["micro"], tpr2["micro"])

all_fpr2 = np.unique(np.concatenate([fpr2[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr2 = np.zeros_like(all_fpr2)
for i in range(n_classes):
    mean_tpr2 += interp(all_fpr2, fpr2[i], tpr2[i])

# Finally average it and compute AUC
mean_tpr2 /= n_classes

fpr2["macro"] = all_fpr2
tpr2["macro"] = mean_tpr2
roc_auc2["macro"] = auc(fpr2["macro"], tpr2["macro"])


################################################################################################
with open('cairo/prediction_60_0-2019-prob.json') as f:
	d = json.load(f)
	data = d['payload']
	y_score3 = []
	y_test3 = []
	for entry in data:
		predicted = entry['Case_Count']
		actual = getHistorical(entry['Event_Date'])
		if actual>1:
			actual = 2
		y_score3.append(predicted)
		y_test3.append(actual)

y_score3 = np.asarray(y_score3)
y_test3 = label_binarize(y_test3, classes=[0, 1, 2])


# Compute ROC curve and ROC area for each class
fpr3 = dict()
tpr3 = dict()
roc_auc3 = dict()
for i in range(2):
    fpr3[i], tpr3[i], _ = roc_curve(y_test3[:, i], y_score3[:, i])
    roc_auc3[i] = auc(fpr3[i], tpr3[i])

# Compute micro-average ROC curve and ROC area
fpr3["micro"], tpr3["micro"], _ = roc_curve(y_test3.ravel(), y_score3.ravel())
roc_auc3["micro"] = auc(fpr3["micro"], tpr3["micro"])

all_fpr3 = np.unique(np.concatenate([fpr3[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr3 = np.zeros_like(all_fpr3)
for i in range(n_classes):
    mean_tpr3 += interp(all_fpr3, fpr3[i], tpr3[i])

# Finally average it and compute AUC
mean_tpr3 /= n_classes

fpr3["macro"] = all_fpr3
tpr3["macro"] = mean_tpr3
roc_auc3["macro"] = auc(fpr3["macro"], tpr3["macro"])

######################################
with open('cairo/prediction_60_3-2019-prob.json') as f:
	d = json.load(f)
	data = d['payload']
	y_score4 = []
	y_test4 = []
	for entry in data:
		predicted = entry['Case_Count']
		actual = getHistorical(entry['Event_Date'])
		if actual>1:
			actual = 2
		y_score4.append(predicted)
		y_test4.append(actual)

y_score4 = np.asarray(y_score4)
y_test4 = label_binarize(y_test4, classes=[0, 1, 2])



# Compute ROC curve and ROC area for each class
fpr4 = dict()
tpr4 = dict()
roc_auc4 = dict()
for i in range(2):
    fpr4[i], tpr4[i], _ = roc_curve(y_test4[:, i], y_score4[:, i])
    roc_auc4[i] = auc(fpr4[i], tpr4[i])

# Compute micro-average ROC curve and ROC area
fpr4["micro"], tpr4["micro"], _ = roc_curve(y_test4.ravel(), y_score4.ravel())
roc_auc4["micro"] = auc(fpr4["micro"], tpr4["micro"])

all_fpr4 = np.unique(np.concatenate([fpr4[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr4 = np.zeros_like(all_fpr4)
for i in range(n_classes):
    mean_tpr4 += interp(all_fpr4, fpr4[i], tpr4[i])

# Finally average it and compute AUC
mean_tpr4 /= n_classes

fpr4["macro"] = all_fpr4
tpr4["macro"] = mean_tpr4
roc_auc4["macro"] = auc(fpr4["macro"], tpr4["macro"])

# ###########################
with open('cairo/prediction_60_7-2019-prob.json') as f:
	d = json.load(f)
	data = d['payload']
	y_score5 = []
	y_test5 = []
	for entry in data:
		predicted = entry['Case_Count']
		actual = getHistorical(entry['Event_Date'])
		if actual>1:
			actual = 2
		y_score5.append(predicted)
		y_test5.append(actual)

y_score5 = np.asarray(y_score5)
y_test5 = label_binarize(y_test5, classes=[0, 1, 2])

# Compute ROC curve and ROC area for each class
fpr5 = dict()
tpr5 = dict()
roc_auc5 = dict()
for i in range(2):
    fpr5[i], tpr5[i], _ = roc_curve(y_test5[:, i], y_score5[:, i])
    roc_auc5[i] = auc(fpr5[i], tpr5[i])

# Compute micro-average ROC curve and ROC area
fpr5["micro"], tpr5["micro"], _ = roc_curve(y_test5.ravel(), y_score5.ravel())
roc_auc5["micro"] = auc(fpr5["micro"], tpr5["micro"])

all_fpr5 = np.unique(np.concatenate([fpr5[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr5 = np.zeros_like(all_fpr5)
for i in range(n_classes):
    mean_tpr5 += interp(all_fpr5, fpr5[i], tpr5[i])

# Finally average it and compute AUC
mean_tpr5 /= n_classes

fpr5["macro"] = all_fpr5
tpr5["macro"] = mean_tpr5
roc_auc5["macro"] = auc(fpr5["macro"], tpr5["macro"])

################################################################################################
def parser(x):
	return datetime.strptime(x, '%Y-%m-%d')
 
series = read_csv('../arima/cairo.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
X = series.values.astype('float32')
size = int(len(X) * 0.95)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
	model = ARIMA(history, order=(5,1,0))
	model_fit = model.fit(disp=0)
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)

y_score6 = []
y_test6 = []
for i in range(len(predictions)):
	predicted = predictions[i]
	if predicted > 0:
		predicted = 1
	else:
		predicted = 0
	actual = np.rint(test[i])
	if test[i]>1:
		actual = 2
	y_score6.append(predicted)
	y_test6.append(actual)

y_score6 = label_binarize(y_score6, classes=[0, 1, 2])
y_test6 = label_binarize(y_test6, classes=[0, 1, 2])


# Compute ROC curve and ROC area for each class
fpr6 = dict()
tpr6 = dict()
roc_auc6 = dict()
for i in range(2):
    fpr6[i], tpr6[i], _ = roc_curve(y_test6[:, i], y_score6[:, i])
    roc_auc6[i] = auc(fpr6[i], tpr6[i])

# Compute micro-average ROC curve and ROC area
fpr6["micro"], tpr6["micro"], _ = roc_curve(y_test6.ravel(), y_score6.ravel())
roc_auc6["micro"] = auc(fpr6["micro"], tpr6["micro"])

n_classes = 2
all_fpr6 = np.unique(np.concatenate([fpr6[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr6 = np.zeros_like(all_fpr6)
for i in range(n_classes):
    mean_tpr6 += interp(all_fpr6, fpr6[i], tpr6[i])

# Finally average it and compute AUC
mean_tpr6 /= n_classes

fpr6["macro"] = all_fpr6
tpr6["macro"] = mean_tpr6
roc_auc6["macro"] = auc(fpr6["macro"], tpr6["macro"])
################################################################################################




plt.figure()
lw = 2
plt.plot(fpr['macro'], tpr['macro'], color='blue',
         lw=lw, label='30 days 0 LT (area = %0.2f)' % roc_auc['macro'], linestyle=':')
plt.plot(fpr1['macro'], tpr1['macro'], color='blue',
         lw=lw, label='30 days 3 LT (area = %0.2f)' % roc_auc1['macro'], linestyle='--')
plt.plot(fpr2['macro'], tpr2['macro'], color='blue',
         lw=lw, label='30 days 7 LT (area = %0.2f)' % roc_auc2['macro'], linestyle='-.')
plt.plot(fpr3['macro'], tpr3['macro'], color='red',
         lw=lw, label='60 days 0 LT (area = %0.2f)' % roc_auc3['macro'], linestyle=':')
plt.plot(fpr4['macro'], tpr4['macro'], color='red',
         lw=lw, label='60 days 3 LT (area = %0.2f)' % roc_auc4['macro'], linestyle='--')
plt.plot(fpr5['macro'], tpr5['macro'], color='red',
         lw=lw, label='60 days 7 LT (area = %0.2f)' % roc_auc5['macro'], linestyle='-.')
plt.plot(fpr6['macro'], tpr6['macro'], color='green',
         lw=lw, label='ARIMA (area = %0.2f)' % roc_auc6['macro'])
# plt.plot([0, 1], [0, 1], color='green', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('macro-average AUC-ROC curve for Cairo, Egypt')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Delhi, India

# %%
def getCounts(date):
	with open('delhi/Delhi_Daily_Counts.json') as f:
		data = json.load(f)
		return data[date]

with open('delhi/prediction_30_0-2019-prob.json') as f:
	d = json.load(f)
	data = d['payload']
	y_score = []
	y_test = []
	for entry in data:
		predicted = entry['Case_Count']
		actual = getCounts(entry['Event_Date'])
		if actual>3:
			actual = 4
		y_score.append(predicted)
		y_test.append(actual)

y_score = np.asarray(y_score)
y_test = label_binarize(y_test, classes=[0, 1, 2, 3, 4])

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(5):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

n_classes = 5
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])


######################################
with open('delhi/prediction_30_3-2019-prob.json') as f:
	d = json.load(f)
	data = d['payload']
	y_score1 = []
	y_test1 = []
	for entry in data:
		predicted = entry['Case_Count']
		actual = getCounts(entry['Event_Date'])
		if actual>3:
			actual = 4
		y_score1.append(predicted)
		y_test1.append(actual)

y_score1 = np.asarray(y_score1)
y_test1 = label_binarize(y_test1, classes=[0, 1, 2, 3, 4])

# Compute ROC curve and ROC area for each class
fpr1 = dict()
tpr1 = dict()
roc_auc1 = dict()
for i in range(5):
    fpr1[i], tpr1[i], _ = roc_curve(y_test1[:, i], y_score1[:, i])
    roc_auc1[i] = auc(fpr1[i], tpr1[i])

# Compute micro-average ROC curve and ROC area
fpr1["micro"], tpr1["micro"], _ = roc_curve(y_test1.ravel(), y_score1.ravel())
roc_auc1["micro"] = auc(fpr1["micro"], tpr1["micro"])

all_fpr1 = np.unique(np.concatenate([fpr1[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr1 = np.zeros_like(all_fpr1)
for i in range(n_classes):
    mean_tpr1 += interp(all_fpr1, fpr1[i], tpr1[i])

# Finally average it and compute AUC
mean_tpr1 /= n_classes

fpr1["macro"] = all_fpr1
tpr1["macro"] = mean_tpr1
roc_auc1["macro"] = auc(fpr1["macro"], tpr1["macro"])


###########################
with open('delhi/prediction_30_7-2019-prob.json') as f:
	d = json.load(f)
	data = d['payload']
	y_score2 = []
	y_test2 = []
	for entry in data:
		predicted = entry['Case_Count']
		actual = getCounts(entry['Event_Date'])
		if actual>3:
				actual = 4
		y_score2.append(predicted)
		y_test2.append(actual)

y_score2 = np.asarray(y_score2)
y_test2 = label_binarize(y_test2, classes=[0, 1, 2, 3, 4])

# Compute ROC curve and ROC area for each class
fpr2 = dict()
tpr2 = dict()
roc_auc2 = dict()
for i in range(5):
    fpr2[i], tpr2[i], _ = roc_curve(y_test2[:, i], y_score2[:, i])
    roc_auc2[i] = auc(fpr2[i], tpr2[i])

# Compute micro-average ROC curve and ROC area
fpr2["micro"], tpr2["micro"], _ = roc_curve(y_test2.ravel(), y_score2.ravel())
roc_auc2["micro"] = auc(fpr2["micro"], tpr2["micro"])

all_fpr2 = np.unique(np.concatenate([fpr2[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr2 = np.zeros_like(all_fpr2)
for i in range(n_classes):
    mean_tpr2 += interp(all_fpr2, fpr2[i], tpr2[i])

# Finally average it and compute AUC
mean_tpr2 /= n_classes

fpr2["macro"] = all_fpr2
tpr2["macro"] = mean_tpr2
roc_auc2["macro"] = auc(fpr2["macro"], tpr2["macro"])

################################################################################################
with open('delhi/prediction_60_0-2019-prob.json') as f:
	d = json.load(f)
	data = d['payload']
	y_score3 = []
	y_test3 = []
	for entry in data:
		predicted = entry['Case_Count']
		actual = getCounts(entry['Event_Date'])
		if actual>3:
			actual = 4
		y_score3.append(predicted)
		y_test3.append(actual)

y_score3 = np.asarray(y_score3)
y_test3 = label_binarize(y_test3, classes=[0, 1, 2, 3, 4])


# Compute ROC curve and ROC area for each class
fpr3 = dict()
tpr3 = dict()
roc_auc3 = dict()
for i in range(5):
    fpr3[i], tpr3[i], _ = roc_curve(y_test3[:, i], y_score3[:, i])
    roc_auc3[i] = auc(fpr3[i], tpr3[i])

# Compute micro-average ROC curve and ROC area
fpr3["micro"], tpr3["micro"], _ = roc_curve(y_test3.ravel(), y_score3.ravel())
roc_auc3["micro"] = auc(fpr3["micro"], tpr3["micro"])

all_fpr3 = np.unique(np.concatenate([fpr3[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr3 = np.zeros_like(all_fpr3)
for i in range(n_classes):
    mean_tpr3 += interp(all_fpr3, fpr3[i], tpr3[i])

# Finally average it and compute AUC
mean_tpr3 /= n_classes

fpr3["macro"] = all_fpr3
tpr3["macro"] = mean_tpr3
roc_auc3["macro"] = auc(fpr3["macro"], tpr3["macro"])

######################################
with open('delhi/prediction_60_3-2019-prob.json') as f:
	d = json.load(f)
	data = d['payload']
	y_score4 = []
	y_test4 = []
	for entry in data:
		predicted = entry['Case_Count']
		actual = getCounts(entry['Event_Date'])
		if actual>3:
			actual = 4
		y_score4.append(predicted)
		y_test4.append(actual)

y_score4 = np.asarray(y_score4)
y_test4 = label_binarize(y_test4, classes=[0, 1, 2, 3, 4])


# Compute ROC curve and ROC area for each class
fpr4 = dict()
tpr4 = dict()
roc_auc4 = dict()
for i in range(5):
    fpr4[i], tpr4[i], _ = roc_curve(y_test4[:, i], y_score4[:, i])
    roc_auc4[i] = auc(fpr4[i], tpr4[i])

# Compute micro-average ROC curve and ROC area
fpr4["micro"], tpr4["micro"], _ = roc_curve(y_test4.ravel(), y_score4.ravel())
roc_auc4["micro"] = auc(fpr4["micro"], tpr4["micro"])

all_fpr4 = np.unique(np.concatenate([fpr4[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr4 = np.zeros_like(all_fpr4)
for i in range(n_classes):
    mean_tpr4 += interp(all_fpr4, fpr4[i], tpr4[i])

# Finally average it and compute AUC
mean_tpr4 /= n_classes

fpr4["macro"] = all_fpr4
tpr4["macro"] = mean_tpr4
roc_auc4["macro"] = auc(fpr4["macro"], tpr4["macro"])


###########################
with open('delhi/prediction_60_7-2019-prob.json') as f:
	d = json.load(f)
	data = d['payload']
	y_score5 = []
	y_test5 = []
	for entry in data:
		# if entry['Case_Count']!=2:
		predicted = entry['Case_Count']
		# if predicted>3:
		# 		predicted = 4
		actual = getCounts(entry['Event_Date'])
		if actual>3:
				actual = 4
		y_score5.append(predicted)
		y_test5.append(actual)


# y_score2 =  np.array([[1] if l==1 else [0] for l in y_score2])
# y_test2 =  np.array([[1] if l==1 else [0] for l in y_test2])
# y_score2 = label_binarize(y_score2, classes=[0, 1, 2, 3, 4])
y_score5 = np.asarray(y_score5)
y_test5 = label_binarize(y_test5, classes=[0, 1, 2, 3, 4])

# print(y_test)

# Compute ROC curve and ROC area for each class
fpr5 = dict()
tpr5 = dict()
roc_auc5 = dict()
for i in range(5):
    fpr5[i], tpr5[i], _ = roc_curve(y_test5[:, i], y_score5[:, i])
    roc_auc5[i] = auc(fpr5[i], tpr5[i])

# Compute micro-average ROC curve and ROC area
fpr5["micro"], tpr5["micro"], _ = roc_curve(y_test5.ravel(), y_score5.ravel())
roc_auc5["micro"] = auc(fpr5["micro"], tpr5["micro"])

all_fpr5 = np.unique(np.concatenate([fpr5[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr5 = np.zeros_like(all_fpr5)
for i in range(n_classes):
    mean_tpr5 += interp(all_fpr5, fpr5[i], tpr5[i])

# Finally average it and compute AUC
mean_tpr5 /= n_classes

fpr5["macro"] = all_fpr5
tpr5["macro"] = mean_tpr5
roc_auc5["macro"] = auc(fpr5["macro"], tpr5["macro"])



################################################################################################
def parser(x):
	return datetime.strptime(x, '%Y-%m-%d')
 
series = read_csv('../arima/delhi.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
X = series.values.astype('float32')
size = int(len(X) * 0.95)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
	model = ARIMA(history, order=(5,1,0))
	model_fit = model.fit(disp=0)
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
# 	print('predicted=%f, expected=%f' % (yhat, obs))
# error = mean_squared_error(test, predictions)
# print('Test MSE: %.3f' % error)

# pyplot.plot(test)
# pyplot.plot(predictions, color='red')
# pyplot.show()

y_score6 = []
y_test6 = []
for i in range(len(predictions)):
	predicted = np.rint(predictions[i])
	if predicted > 3:
		predicted = np.asarray([4])
	actual = np.rint(test[i])
	if test[i]>3:
		actual = np.asarray([4])
	y_score6.append(predicted)
	y_test6.append(actual)

# print(y_score)

y_score6 = label_binarize(y_score6, classes=[0, 1, 2, 3, 4])
y_test6 = label_binarize(y_test6, classes=[0, 1, 2, 3, 4])


# Compute ROC curve and ROC area for each class
fpr6 = dict()
tpr6 = dict()
roc_auc6 = dict()
for i in range(5):
    fpr6[i], tpr6[i], _ = roc_curve(y_test6[:, i], y_score6[:, i])
    roc_auc6[i] = auc(fpr6[i], tpr6[i])

# Compute micro-average ROC curve and ROC area
fpr6["micro"], tpr6["micro"], _ = roc_curve(y_test6.ravel(), y_score6.ravel())
roc_auc6["micro"] = auc(fpr6["micro"], tpr6["micro"])


all_fpr6 = np.unique(np.concatenate([fpr6[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr6 = np.zeros_like(all_fpr6)
for i in range(n_classes):
    mean_tpr6 += interp(all_fpr6, fpr6[i], tpr6[i])

# Finally average it and compute AUC
mean_tpr6 /= n_classes

fpr6["macro"] = all_fpr6
tpr6["macro"] = mean_tpr6
roc_auc6["macro"] = auc(fpr6["macro"], tpr6["macro"])
################################################################################################






plt.figure()
lw = 2
plt.plot(fpr['macro'], tpr['macro'], color='blue',
         lw=lw, label='30 days 0 LT (area = %0.2f)' % roc_auc['macro'], linestyle=':')
plt.plot(fpr1['macro'], tpr1['macro'], color='blue',
         lw=lw, label='30 days 3 LT (area = %0.2f)' % roc_auc1['macro'], linestyle='--')
plt.plot(fpr2['macro'], tpr2['macro'], color='blue',
         lw=lw, label='30 days 7 LT (area = %0.2f)' % roc_auc2['macro'], linestyle='-.')
plt.plot(fpr3['macro'], tpr3['macro'], color='red',
         lw=lw, label='60 days 0 LT (area = %0.2f)' % roc_auc3['macro'], linestyle=':')
plt.plot(fpr4['macro'], tpr4['macro'], color='red',
         lw=lw, label='60 days 3 LT (area = %0.2f)' % roc_auc4['macro'], linestyle='--')
plt.plot(fpr5['macro'], tpr5['macro'], color='red',
         lw=lw, label='60 days 7 LT (area = %0.2f)' % roc_auc5['macro'], linestyle='-.')
plt.plot(fpr6['macro'], tpr6['macro'], color='green',
         lw=lw, label='ARIMA (area = %0.2f)' % roc_auc6['macro'])
# plt.plot([0, 1], [0, 1], color='green', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('macro-average AUC-ROC curve for Delhi, India')
plt.legend(loc="lower right")
plt.show()
